# %%
1. In the below elements which of them are values or an expression? eg:- values can be
integer or string and expressions will be mathematical operators.

Solution: 
    
* = Mathematical operator

'hello' = String

-87.8 = Float 

- = Mathematical operator

/ = Mathematical operator

+ = Mathematical operator

6 = integer

2. What is the difference between string and variable?

Solution:
    
    varible:The Varible is defined as something which hold a values and the assigned values can be changed by the user.
        
        Eg:test=3
            print(test)
           = 3
        
    String:The String is the sequence or a list of character in order, the character should be always be present inside a 
        single or double quotes.
     
        Eg:test1=("Hello world")
             print(test1)
               = Hello world 

3. Describe three different data types.

Solution:
   (1) Numeric data types: This data type is used to hold numerical values like
   eg:int - holds signed integers of non-limited length.
      float- holds floating precision numbers and it’s accurate up to 15 decimal places.
      complex- holds complex numbers.
        
   (2) String Data Type: This data type is used to store sequence or a list of character in order and the characters should be 
    always be enclosed in single or double quotes.
    
   (3) Boolean data type: It is one of the built in data types which represent one of two types which is either true or false.
    

4. What is an expression made up of? What do all expressions do? 

Solution:An expression is a combination of operators and operands that is interpreted to produce some other value.
    it mainly used for the representation of values it .String can be also considered as expression as it represent a value.
    
    
5. This assignment statements, like spam = 10. What is the difference between an
expression and a statement?

Solution:Expression is used for the representation of values where Statment is used for resource management and exception 
    handling.
    
6. After running the following code, what does the variable bacon contain?
bacon = 22
bacon + 1

Solution:23

7. What should the values of the following two terms be?
'spam'+'spamspam'
'spam'*3
  
Solution: 'spamspamspam'

8. Why is eggs a valid variable name while 100 is invalid?
Solution:egg is considered as string and 100 is a integer. in python only string can be used as a varible ans integer cannot
    be assigned as a varible.
      
9. What three functions can be used to get the integer, floating-point number, or string
version of a value?        
Solution:int(), float(), and str() functions will evaluate to the integer, floating-point number, and string 
        
10. Why does this expression cause an error? How can you fix it?       
'i have eaten'+99+'burritos'

Solution:an only concatenate str (not "int") to str.
    it can be corrected by placing 99 in single quotes
    
    'i have eaten'+'99'+'burritos'
       = 'i have eaten99burritos'
